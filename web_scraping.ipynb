# %% [markdown]
# # Web scraping

# %%
import re
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
#==================================================================================================================
def city_coordinates(CityName):
    url = f'https://en.wikipedia.org/wiki/{CityName}'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    wiki_info = soup.find_all('table', class_  = 'infobox ib-settlement vcard')[0]
    
    latitude = wiki_info.find_all('span', class_ = 'latitude')[0].get_text()
    longitude = wiki_info.find_all('span', class_ = 'longitude')[0].get_text() 

    label = wiki_info.find_all('th', scope = 'row', class_ = 'infobox-label')
    data = wiki_info.find_all('td', class_ = 'infobox-data')
    box = wiki_info.find_all('tr', class_ = 'mergedtoprow')

    for i in range(len(box)):
        box_header_title = box[i].get_text()
        if re.search('Population', box_header_title): 

            date = box_header_title
            
            pop = box[i].find_next('td').get_text()
            # pop = re.split(r' |\[', pop)[0]
            break
    
    for i in range(len(data)):
        the_label = label[i].get_text().lower()
        if re.search('country', the_label):
            country = data[i].get_text().strip()
            break
    
    return [CityName, latitude, longitude, country, date, pop]

#==================================================================================================================
def to_decimal_coordinate(coordinates):
    latitude, longitude = coordinates['Latitude'], coordinates['Longitude']
    
    latitude, longitude = re.split('°|′|″', latitude), re.split('°|′|″', longitude)
    
    latitude = (float(latitude[0]) + float(latitude[1])/60)*((latitude[-1] == 'N') - (latitude[-1] == 'S'))
    longitude = (float(longitude[0]) + float(longitude[1])/60)*((longitude[-1] == 'E') - (longitude[-1] == 'W'))

    return [latitude, longitude]

#==================================================================================================================
def extract_the_year(info):
    date = info['YearDataRetrieved']
    # Find the characters between the parenthesis
    pattern = r'\(([^)]+)\)'
    match = re.search(pattern, date)
    # Extract the matching value
    date = match.group(1)

    # Find only integers with 4 digits
    pattern = r'\b(\d{4})\b'
    match = re.search(pattern, date)
    year = match.group(1)

    return year

#==================================================================================================================
def extract_the_population(info):
    # pop = info['Population']
    # Replace the character ',' by ''
    info = info.replace(',', '')
    
    # Find the firt characters that is an integer
    pattern = r'^\d+'
    match = re.search(pattern, info)
    
    return match.group()

# %%
# city = ['Berlin', 'Hamburg', 'Munich']
new_cities = ['Berlin', 'Hamburg', 'Munich', 'Ottawa', 'Lyon', 'Vienna', 'Brazilia', 'Dublin', 'Barcelona', 'Mexico City', 'Pretoria', 'Seoul', 'Tokyo', 'Paris', 'New_York_City']

scraping_city_df = pd.DataFrame()
for i in range(len(new_cities)):
    scraping_city_df.loc[i,['CityName', 'Latitude', 'Longitude', 'CountryName', 'YearDataRetrieved', 'Population']]  = city_coordinates(new_cities[i])
scraping_city_df
# Out:
#          CityName    Latitude   Longitude    CountryName  \
# 0          Berlin  52°31′12″N  13°24′18″E        Germany
# 1         Hamburg     53°33′N     10°00′E        Germany
# 2          Munich  48°08′15″N  11°34′30″E        Germany
# 3          Ottawa  45°25′29″N  75°41′42″W         Canada
# 4            Lyon     45°46′N      4°50′E         France
# 5          Vienna  48°12′30″N  16°22′21″E        Austria
# 6        Brazilia  15°47′38″S  47°52′58″W         Brazil
# 7          Dublin  53°21′00″N  06°15′37″W        Ireland
# 8       Barcelona     41°23′N      2°11′E          Spain
# 9     Mexico City     19°26′N      99°8′W         Mexico
# 10       Pretoria  25°44′46″S  28°11′17″E   South Africa
# 11          Seoul     37°34′N    126°59′E    South Korea
# 12          Tokyo     35°41′N    139°46′E          Japan
# 13          Paris  48°51′24″N    2°21′8″E         France
# 14  New_York_City  40°42′46″N   74°0′22″W  United States
#
#                     YearDataRetrieved                      Population
# 0         Population (2022 census)[4]                       3,596,999
# 1          Population (2023-12-31)[2]                       1,964,021
# 2          Population (2023-12-31)[2]                       1,510,378
# 3                   Population (2021)                 1,017,449 (4th)
# 4         Population (2022)[5]520,774                         520,774
# 5       Population (2024)[1]2,014,614                       2,014,614
# 6                   Population (2022)  2,817,381[1][2] (3rd) [note 1]
# 7                   Population (2022)                      592,713[3]
# 8                Population (2018)[5]                       1,620,343
# 9                Population (2020)[8]                       9,209,944
# 10               Population (2023)[1]                       2,818,100
# 11            Population (2Q 2023)[4]                       9,659,322
# 12               Population (2024)[5]                      14,187,176
# 13  Population (Jan 2025[3])2,048,472                       2,048,472
# 14               Population (2020)[4]                       8,804,190

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### We convert the coordinates to decimal coordinates

# %%
scraping_city_df[['Latitude', 'Longitude']] = list(
    scraping_city_df[['Latitude', 'Longitude']]
    .apply(to_decimal_coordinate, axis = 1)
)
scraping_city_df
# Out:
#          CityName   Latitude   Longitude    CountryName  \
# 0          Berlin  52.516667   13.400000        Germany
# 1         Hamburg  53.550000   10.000000        Germany
# 2          Munich  48.133333   11.566667        Germany
# 3          Ottawa  45.416667  -75.683333         Canada
# 4            Lyon  45.766667    4.833333         France
# 5          Vienna  48.200000   16.366667        Austria
# 6        Brazilia -15.783333  -47.866667         Brazil
# 7          Dublin  53.350000   -6.250000        Ireland
# 8       Barcelona  41.383333    2.183333          Spain
# 9     Mexico City  19.433333  -99.133333         Mexico
# 10       Pretoria -25.733333   28.183333   South Africa
# 11          Seoul  37.566667  126.983333    South Korea
# 12          Tokyo  35.683333  139.766667          Japan
# 13          Paris  48.850000    2.350000         France
# 14  New_York_City  40.700000  -74.000000  United States
#
#                     YearDataRetrieved                      Population
# 0         Population (2022 census)[4]                       3,596,999
# 1          Population (2023-12-31)[2]                       1,964,021
# 2          Population (2023-12-31)[2]                       1,510,378
# 3                   Population (2021)                 1,017,449 (4th)
# 4         Population (2022)[5]520,774                         520,774
# 5       Population (2024)[1]2,014,614                       2,014,614
# 6                   Population (2022)  2,817,381[1][2] (3rd) [note 1]
# 7                   Population (2022)                      592,713[3]
# 8                Population (2018)[5]                       1,620,343
# 9                Population (2020)[8]                       9,209,944
# 10               Population (2023)[1]                       2,818,100
# 11            Population (2Q 2023)[4]                       9,659,322
# 12               Population (2024)[5]                      14,187,176
# 13  Population (Jan 2025[3])2,048,472                       2,048,472
# 14               Population (2020)[4]                       8,804,190

# %% [markdown]
# ### We extract the Year

# %%
scraping_city_df['YearDataRetrieved']  = scraping_city_df[['YearDataRetrieved']].apply(extract_the_year, axis = 1)
scraping_city_df
# Out:
#          CityName   Latitude   Longitude    CountryName YearDataRetrieved  \
# 0          Berlin  52.516667   13.400000        Germany              2022
# 1         Hamburg  53.550000   10.000000        Germany              2023
# 2          Munich  48.133333   11.566667        Germany              2023
# 3          Ottawa  45.416667  -75.683333         Canada              2021
# 4            Lyon  45.766667    4.833333         France              2022
# 5          Vienna  48.200000   16.366667        Austria              2024
# 6        Brazilia -15.783333  -47.866667         Brazil              2022
# 7          Dublin  53.350000   -6.250000        Ireland              2022
# 8       Barcelona  41.383333    2.183333          Spain              2018
# 9     Mexico City  19.433333  -99.133333         Mexico              2020
# 10       Pretoria -25.733333   28.183333   South Africa              2023
# 11          Seoul  37.566667  126.983333    South Korea              2023
# 12          Tokyo  35.683333  139.766667          Japan              2024
# 13          Paris  48.850000    2.350000         France              2025
# 14  New_York_City  40.700000  -74.000000  United States              2020
#
#                         Population
# 0                        3,596,999
# 1                        1,964,021
# 2                        1,510,378
# 3                  1,017,449 (4th)
# 4                          520,774
# 5                        2,014,614
# 6   2,817,381[1][2] (3rd) [note 1]
# 7                       592,713[3]
# 8                        1,620,343
# 9                        9,209,944
# 10                       2,818,100
# 11                       9,659,322
# 12                      14,187,176
# 13                       2,048,472
# 14                       8,804,190

# %% [markdown]
# ### We extract the number of populations

# %%
scraping_city_df['Population'] = scraping_city_df['Population'].apply(extract_the_population)

# %% [markdown]
# ### Set the appropriate Data Types

# %%
# Set the appropriate Data types
scraping_city_df['Population'] = pd.to_numeric(scraping_city_df['Population'])
scraping_city_df['YearDataRetrieved'] = pd.to_numeric(scraping_city_df['YearDataRetrieved'])
scraping_city_df.info()
# Out:
#          CityName   Latitude   Longitude    CountryName YearDataRetrieved  \
# 0          Berlin  52.516667   13.400000        Germany              2022
# 1         Hamburg  53.550000   10.000000        Germany              2023
# 2          Munich  48.133333   11.566667        Germany              2023
# 3          Ottawa  45.416667  -75.683333         Canada              2021
# 4            Lyon  45.766667    4.833333         France              2022
# 5          Vienna  48.200000   16.366667        Austria              2024
# 6        Brazilia -15.783333  -47.866667         Brazil              2022
# 7          Dublin  53.350000   -6.250000        Ireland              2022
# 8       Barcelona  41.383333    2.183333          Spain              2018
# 9     Mexico City  19.433333  -99.133333         Mexico              2020
# 10       Pretoria -25.733333   28.183333   South Africa              2023
# 11          Seoul  37.566667  126.983333    South Korea              2023
# 12          Tokyo  35.683333  139.766667          Japan              2024
# 13          Paris  48.850000    2.350000         France              2025
# 14  New_York_City  40.700000  -74.000000  United States              2020
#
#     Population
# 0      3596999
# 1      1964021
# 2      1510378
# 3      1017449
# 4       520774
# 5      2014614
# 6      2817381
# 7       592713
# 8      1620343
# 9      9209944
# 10     2818100
# 11     9659322
# 12    14187176
# 13     2048472
# 14     8804190

# %% [markdown]
# # Connecting to MySQL

# %%
schema = "metropolis"
host = "127.0.0.1"
user = "root"
password = "mysql_password"
port = 3306

connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %% [markdown]
# ## Creating the tables with Python

# %% [markdown]
# ### Table `city`

# %%
city_df = pd.DataFrame(data = scraping_city_df['CityName'].unique(),
                       columns = ['CityName'])
city_df
# Out:
#          CityName
# 0          Berlin
# 1         Hamburg
# 2          Munich
# 3          Ottawa
# 4            Lyon
# 5          Vienna
# 6        Brazilia
# 7          Dublin
# 8       Barcelona
# 9     Mexico City
# 10       Pretoria
# 11          Seoul
# 12          Tokyo
# 13          Paris
# 14  New York City

# %% [markdown]
# ### Table `geo_loc`

# %%
geo_loc_df = pd.DataFrame(data = scraping_city_df[['Latitude', 'Longitude']],
                         columns = ['Latitude', 'Longitude'])
geo_loc_df
# Out:
#      Latitude   Longitude
# 0       52.52      13.405
# 1       53.55        10.0
# 2     48.1375      11.575
# 3   45.424722     -75.695
# 4   45.766667    4.833333
# 5   48.208333     16.3725
# 6  -15.793889  -47.882778
# 7       53.35   -6.260278
# 8   41.383333    2.183333
# 9   19.433333  -99.133333
# 10 -25.746111   28.188056
# 11  37.566667  126.983333
# 12  35.683333  139.766667
# 13  48.856667    2.352222
# 14  40.712778  -74.006111

# %% [markdown]
# ## Creating the matching tables on MySQL

# %% [raw]
# /***************************
# Setting up the environment
# ***************************/
# DROP DATABASE IF EXISTS metropolis;
# CREATE DATABASE metropolis;
# USE metropolis;
#
# /***************************
# Creating the table 'city'
# ***************************/
# CREATE TABLE city (
#     CityId INT AUTO_INCREMENT,
#     CityName VARCHAR(255) NOT NULL,
#     PRIMARY KEY (CityId)
# );
#
# /***************************
# Creating the table 'geolocation'
# ***************************/
# CREATE TABLE geolocation (
#     LocId INT AUTO_INCREMENT,
#     Latitude FLOAT,
#     Longitude FLOAT,
#     CityId INT,
#     PRIMARY KEY (LocId),
#     FOREIGN KEY (CityId) REFERENCES City (CityId)
# );
# /***************************
# Creating the table 'country'
# ***************************/
# CREATE TABLE country (
#     CountryId INT AUTO_INCREMENT,
#     CountryName VARCHAR(45) NOT NULL,
#     CityId INT,
#     PRIMARY KEY (CountryId),
#     FOREIGN KEY (CityId) REFERENCES City (CityId)
# );
#
# /***************************
# Creating the table 'population'
# ***************************/
# CREATE TABLE population (
#     FactId INT AUTO_INCREMENT,
#     YearDataRetrieved YEAR,
#     Population INT,
#     CityId INT,
#     PRIMARY KEY (FactId),
#     FOREIGN KEY (CityId) REFERENCES City (CityId)
# );

# %% [markdown]
# ## Sending it to MySQL

# %%
city_df.to_sql('city',
                  if_exists='append',
                  con=connection_string,
                  index=False)
# Out:
# 15

# %% [markdown]
# ## Receiving from MySQL

# %%
query = '''
SELECT *
FROM city
'''
city_from_sql = pd.read_sql(sql = query, con=connection_string)
city_from_sql
# Out:
#     CityId       CityName
# 0        1         Berlin
# 1        2        Hamburg
# 2        3         Munich
# 3        4         Ottawa
# 4        5           Lyon
# 5        6         Vienna
# 6        7       Brazilia
# 7        8         Dublin
# 8        9      Barcelona
# 9       10    Mexico City
# 10      11       Pretoria
# 11      12          Seoul
# 12      13          Tokyo
# 13      14          Paris
# 14      15  New York City

# %% [markdown]
# ## Sending other tables to MySQL

# %% [markdown]
# ### Country

# %%
country_df = scraping_city_df.merge(city_from_sql, on = 'CityName', how = 'left')
country_df.drop(columns = ['CityName', 'Latitude', 'Longitude', 'YearDataRetrieved', 'Population'],
               inplace = True)
# country_df

# %%
country_df.to_sql('country',
                  if_exists='append',
                  con=connection_string,
                  index=False)
# Out:
# 15

# %% [markdown]
# ### Geo Localisation

# %%
geo_loc_df = scraping_city_df.merge(city_from_sql, on = 'CityName', how = 'left')
geo_loc_df.drop(columns = ['CountryName', 'YearDataRetrieved', 'Population', 'CityName'],
               inplace = True)
geo_loc_df
# Out:
#      Latitude   Longitude  CityId
# 0       52.52      13.405       1
# 1       53.55        10.0       2
# 2     48.1375      11.575       3
# 3   45.424722     -75.695       4
# 4   45.766667    4.833333       5
# 5   48.208333     16.3725       6
# 6  -15.793889  -47.882778       7
# 7       53.35   -6.260278       8
# 8   41.383333    2.183333       9
# 9   19.433333  -99.133333      10
# 10 -25.746111   28.188056      11
# 11  37.566667  126.983333      12
# 12  35.683333  139.766667      13
# 13  48.856667    2.352222      14
# 14  40.712778  -74.006111      15

# %%
geo_loc_df.to_sql('geolocation',
                  if_exists='append',
                  con=connection_string,
                  index=False)
# Out:
# 15

# %% [markdown]
# ### Population

# %%
population_df = scraping_city_df.merge(city_from_sql, on = 'CityName', how = 'left')
population_df.drop(columns = ['CountryName', 'Latitude', 'Longitude', 'CityName'],
               inplace = True)
population_df
# Out:
#    YearDataRetrieved Population  CityId
# 0               2022    3596999       1
# 1               2023    1964021       2
# 2               2023    1510378       3
# 3               2021    1017449       4
# 4               2022     520774       5
# 5               2024    2014614       6
# 6               2022    2817381       7
# 7               2022     592713       8
# 8               2018    1620343       9
# 9               2020    9209944      10
# 10              2023    2818100      11
# 11              2023    9659322      12
# 12              2024   14187176      13
# 13              2025    2048472      14
# 14              2020    8804190      15

# %%
population_df.to_sql('population',
                  if_exists='append',
                  con=connection_string,
                  index=False)
# Out:
# 15
